# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load pickled data
import pickle
import numpy as np
from matplotlib import pyplot
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from pandas.io.parsers import read_csv


## Loading datasets
training_file = '/content/drive/MyDrive/Dataset/GTSDS/train.p'
validation_file='/content/drive/MyDrive/Dataset/GTSDS/valid.p'
testing_file = '/content/drive/MyDrive/Dataset/GTSDS/test.p'

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(validation_file, mode='rb') as f:
    valid = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)

sign_names = read_csv("/content/drive/MyDrive/Dataset/GTSDS/signname.csv").values[:, 1]

#Separating features and labels
X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
#Dataset Summary & Exploration
# Number of training examples
n_train = X_train.shape[0]
# Number of validation examples
n_validation = X_valid.shape[0]
# Number of testing examples.
n_test = X_test.shape[0]
# What's the shape of an traffic sign image?
image_shape = X_train[0].shape
# Unique classes/labels there are in the dataset.
classes, class_indices, class_counts  = np.unique(y_train, return_index=True, return_counts=True)
n_classes = len(class_counts)


print("Number of training examples =", n_train)
print("Number of validation examples =", n_validation)
print("Number of testing examples =", n_test)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)
# Out:
# Number of training examples = 34799
# Number of validation examples = 4410
# Number of testing examples = 12630
# Image data shape = (32, 32, 3)
# Number of classes = 43

# %%
# Cell 3: Plot Class Distributions

def plot_class_distribution(y, title):
    plt.figure(figsize=(20, 5))
    unique_labels, label_counts = np.unique(y, return_counts=True)
    plt.bar(unique_labels, label_counts)
    plt.title(title, fontsize=22)
    plt.xlabel('Class Number (0-42)', fontsize=20)
    plt.ylabel('Number of Occurrences', fontsize=20)
    plt.tick_params(labelsize=16)
    plt.grid(linestyle=':')
    plt.show()

plot_class_distribution(y_train, 'Training Set Class Distribution')
plot_class_distribution(y_test, 'Testing Set Class Distribution')
plot_class_distribution(y_valid, 'Validation Set Class Distribution')

# %%
#Visualizations of image datasets for each class
for c, c_i, c_count in zip(classes, class_indices, class_counts):
    print(c, ". Class : ", sign_names[c] )
    fig = pyplot.figure(figsize = (18, 1))
    fig.subplots_adjust(left = 0, right = 1, bottom = 0, top = 1, hspace = 0.05, wspace = 0.05)
    for i in range(10):
        axis = fig.add_subplot(1, 10, i + 1, xticks=[], yticks=[])
        random_indices = np.random.randint(c_i, c_i+c_count, 10)
        axis.imshow(X_train[random_indices[i],:,:,:])
    pyplot.show()
# Out:
# 0 . Class :  Speed limit (20km/h)
# 1 . Class :  Speed limit (30km/h)
# 2 . Class :  Speed limit (50km/h)
# 3 . Class :  Speed limit (60km/h)
# 4 . Class :  Speed limit (70km/h)
# 5 . Class :  Speed limit (80km/h)
# 6 . Class :  End of speed limit (80km/h)
# 7 . Class :  Speed limit (100km/h)
# 8 . Class :  Speed limit (120km/h)
# 9 . Class :  No passing
# 10 . Class :  No passing for vehicles over 3.5 metric tons
# 11 . Class :  Right-of-way at the next intersection
# 12 . Class :  Priority road
# 13 . Class :  Yield
# 14 . Class :  Stop
# 15 . Class :  No vehicles
# 16 . Class :  Vehicles over 3.5 metric tons prohibited
# 17 . Class :  No entry
# 18 . Class :  General caution
# 19 . Class :  Dangerous curve to the left
# 20 . Class :  Dangerous curve to the right
# 21 . Class :  Double curve
# 22 . Class :  Bumpy road
# 23 . Class :  Slippery road
# 24 . Class :  Road narrows on the right
# 25 . Class :  Road work
# 26 . Class :  Traffic signals
# 27 . Class :  Pedestrians
# 28 . Class :  Children crossing
# 29 . Class :  Bicycles crossing
# 30 . Class :  Beware of ice/snow
# 31 . Class :  Wild animals crossing
# 32 . Class :  End of all speed and passing limits
# 33 . Class :  Turn right ahead
# 34 . Class :  Turn left ahead
# 35 . Class :  Ahead only
# 36 . Class :  Go straight or right
# 37 . Class :  Go straight or left
# 38 . Class :  Keep right
# 39 . Class :  Keep left
# 40 . Class :  Roundabout mandatory
# 41 . Class :  End of no passing
# 42 . Class :  End of no passing by vehicles over 3.5 metric

# %%
# Showing Random Image Datasets for Each Class

def plot_random_each_class(n_row, n_col, X, y):

    plt.figure(figsize=(25, 15))
    gs1 = gridspec.GridSpec(n_row, n_row)
    gs1.update(wspace=0.01, hspace=0.01)  # set the spacing between axes.

    for c, c_i, c_count in zip(classes, class_indices, class_counts):
        ax1 = plt.subplot(gs1[c])
        plt.axis('on')
        ax1.set_xticklabels([])
        ax1.set_yticklabels([])
        ax1.set_aspect('equal')
        ind_plot = np.random.randint(c_i, c_i+c_count)
        plt.imshow(X[ind_plot])
        plt.text(0, 0, '{}: {:.20}'.format(c, sign_names[c]), color='k', backgroundcolor='c', fontsize=12)
        plt.axis('off')

    plt.show()

plot_random_each_class(7, 7, X_train, y_train)

# %%
# Cell 6: Data Augmentation

# Data Augmentation
from skimage.transform import rotate
from skimage.transform import warp
from skimage.transform import ProjectiveTransform
import cv2

def rotate_image(image, max_angle=15):
    rotate_out = rotate(image, np.random.uniform(-max_angle, max_angle), mode='edge')
    return rotate_out

def translate_image(image, max_trans=5, height=32, width=32):
    translate_x = max_trans * np.random.uniform() - max_trans/2
    translate_y = max_trans * np.random.uniform() - max_trans/2
    translation_mat = np.float32([[1, 0, translate_x], [0, 1, translate_y]])
    trans = cv2.warpAffine(image, translation_mat, (height, width))
    return trans

def projection_transform(image, max_warp=0.8, height=32, width=32):
    d = height * 0.3 * np.random.uniform(0, max_warp)
    tl_top = np.random.uniform(-d, d)
    tl_left = np.random.uniform(-d, d)
    bl_bottom = np.random.uniform(-d, d)
    bl_left = np.random.uniform(-d, d)
    tr_top = np.random.uniform(-d, d)
    tr_right = np.random.uniform(-d, d)
    br_bottom = np.random.uniform(-d, d)
    br_right = np.random.uniform(-d, d)

    transform = ProjectiveTransform()
    transform.estimate(np.array(((tl_left, tl_top), (bl_left, height - bl_bottom),
                                 (height - br_right, height - br_bottom), (height - tr_right, tr_top))),
                       np.array(((0, 0), (0, height), (height, height), (height, 0))))
    output_image = warp(image, transform, output_shape=(height, width), order=1, mode='edge')
    return output_image

# %%
#More Data Augmentation

def transform_image(image, max_angle=15, max_trans=5, max_warp=0.8):
    height, width, channels = image.shape
    rotated_image = rotate_image(image, max_angle)
    translated_image = translate_image(rotated_image, max_trans, height, width)
    output_image = projection_transform(translated_image, max_warp, height, width)
    return (output_image * 255.0).astype(np.uint8)


def augment_and_balance_data(X_train, y_train, no_examples_per_class=5000):

    n_examples = no_examples_per_class
    X_balance = np.empty([0, X_train.shape[1], X_train.shape[2], X_train.shape[3]], dtype=np.float32)
    y_balance = np.empty([0], dtype=y_train.dtype)

    for c, count in zip(range(n_classes), class_counts):
        X_orig = X_train[y_train == c]
        y_orig = y_train[y_train == c]
        X_balance = np.append(X_balance, X_orig, axis=0)
        temp_X = np.empty([n_examples - count, X_train.shape[1], X_train.shape[2], X_train.shape[3]], dtype=np.float32)
        for i in range(n_examples - count):
            temp_X[i, :, :, :] = transform_image(X_orig[i % count])
        X_balance = np.append(X_balance, temp_X, axis=0)
        n_added_ex = X_balance.shape[0] - y_balance.shape[0]
        y_balance = np.append(y_balance, np.full(n_added_ex, c, dtype=int))

    return X_balance.astype(np.uint8), y_balance

# %%
#Data Preprocessig
from sklearn.utils import shuffle

## Shuffle the dataset
X_train, y_train = shuffle(X_train, y_train)
# Convert RGB images to grayscale for the training set
X_train_gray = np.sum(X_train/3, axis=3, keepdims=True)

# Convert RGB images to grayscale for the testing set
X_test_gray  = np.sum(X_test/3, axis=3, keepdims=True)

# Convert RGB images to grayscale for the validation set
X_validation_gray  = np.sum(X_valid/3, axis=3, keepdims=True)
# Normalize the training set of grayscale images
X_train_gray_norm = (X_train_gray - 32) / 32

# Normalize the test set of grayscale images
X_test_gray_norm = (X_test_gray - 32) / 32

# Normalize the validation set of grayscale images
X_validation_gray_norm = (X_validation_gray - 32) / 32

# %%
# Onehot Encoding the labels.
from tensorflow.keras.utils import to_categorical

# Store the original labels for future reference
y_train_unchanged = y_train
y_validation_unchanged = y_valid
y_test_unchanged = y_test

# Perform Onehot Encoding on the labels
# Convert the labels from integer representation to binary matrix representation
y_train = to_categorical(y_train)
y_validation = to_categorical(y_valid)
y_test = to_categorical(y_test)
# Shape of Train dataset
print(X_train.shape)

# Shape of Test dataset
print(X_test.shape)

# Shape of Validation dataset
print(X_valid.shape)
# Out:
# (34799, 32, 32, 3)
# (12630, 32, 32, 3)
# (4410, 32, 32, 3)

# %%
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense, MaxPooling2D, Dropout
from tensorflow.keras.models import Sequential
import tensorflow as tf

# Create a sequential model
model = Sequential()

# Add a convolutional layer with 32 filters, 3x3 kernel size, 'same' padding, and ReLU activation
model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 1)))

# Add another convolutional layer with 32 filters, 3x3 kernel size, and ReLU activation
model.add(Conv2D(32, (3, 3), activation='relu'))

# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))

# Add a dropout layer with a rate of 0.25
model.add(Dropout(0.25))

# Add more convolutional and pooling layers, followed by dropout
model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Flatten the output from the previous layer
model.add(Flatten())

# Add a fully connected layer with 512 units and ReLU activation
model.add(Dense(512, activation='relu'))

# Add a dropout layer with a rate of 0.5
model.add(Dropout(0.5))

# Add the output layer with 43 units (corresponding to the number of classes) and softmax activation
model.add(Dense(43, activation='softmax'))

# Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  conv2d_4 (Conv2D)           (None, 6, 6, 64)          36928
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 64)          36928
#
#  max_pooling2d_2 (MaxPoolin  (None, 2, 2, 64)          0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 2, 2, 64)          0
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 512)               131584
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 43)                22059
#
# =================================================================
# Total params: 292491 (1.12 MB)
# Trainable params: 292491 (1.12 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

# Define early stopping callback to monitor validation loss and stop training if it doesn't improve for 30 epochs
stop = EarlyStopping(monitor='val_loss', mode='min', patience=30)

# Define model checkpoint callback to save the best model based on validation loss
mc = ModelCheckpoint('best_CNN_model.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

# Compile the model with the specified loss, optimizer, and metrics
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.001),
              metrics=['accuracy'])

# Train the model on the training data
history = model.fit(X_train_gray_norm, y_train,
                    batch_size=500,
                    epochs=100,
                    verbose=1,
                    validation_data=(X_validation_gray_norm, y_validation),
                    shuffle=True,
                    callbacks=[stop, mc])
# Out:
# Epoch 1/100
# 70/70 [==============================] - ETA: 0s - loss: 3.2833 - accuracy: 0.1238
# Epoch 1: val_loss improved from inf to 2.38406, saving model to best_CNN_model.h5
# 70/70 [==============================] - 13s 65ms/step - loss: 3.2833 - accuracy: 0.1238 - val_loss: 2.3841 - val_accuracy: 0.4011
# Epoch 2/100
#  3/70 [>.............................] - ETA: 2s - loss: 2.3824 - accuracy: 0.3607
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 69/70 [============================>.] - ETA: 0s - loss: 1.3252 - accuracy: 0.6134
# Epoch 2: val_loss improved from 2.38406 to 0.50644, saving model to best_CNN_model.h5
# 70/70 [==============================] - 3s 39ms/step - loss: 1.3196 - accuracy: 0.6148 - val_loss: 0.5064 - val_accuracy: 0.8449
# Epoch 3/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.4672 - accuracy: 0.8532
# Epoch 3: val_loss improved from 0.50644 to 0.25813, saving model to best_CNN_model.h5
# 70/70 [==============================] - 3s 39ms/step - loss: 0.4661 - accuracy: 0.8535 - val_loss: 0.2581 - val_accuracy: 0.9166
# Epoch 4/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.2715 - accuracy: 0.9139
# Epoch 4: val_loss improved from 0.25813 to 0.21310, saving model to best_CNN_model.h5
# 70/70 [==============================] - 3s 39ms/step - loss: 0.2709 - accuracy: 0.9141 - val_loss: 0.2131 - val_accuracy: 0.9374
# Epoch 5/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.1835 - accuracy: 0.9429
# Epoch 5: val_loss improved from 0.21310 to 0.17821, saving model to best_CNN_model.h5
# 70/70 [==============================] - 3s 39ms/step - loss: 0.1834 - accuracy: 0.9430 - val_loss: 0.1782 - val_accuracy: 0.9488
# Epoch 6/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.1421 - accuracy: 0.9560
# Epoch 6: val_loss improved from 0.17821 to 0.14062, saving model to best_CNN_model.h5
# 70/70 [==============================] - 3s 38ms/step - loss: 0.1417 - accuracy: 0.9562 - val_loss: 0.1406 - val_accuracy: 0.9610
# Epoch 7/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.1151 - accuracy: 0.9637
# Epoch 7: val_loss improved from 0.14062 to 0.12253, saving model to best_CNN_model.h5
# 70/70 [==============================] - 3s 40ms/step - loss: 0.1149 - accuracy: 0.9638 - val_loss: 0.1225 - val_accuracy: 0.9671
# Epoch 8/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0936 - accuracy: 0.9705
# Epoch 8: val_loss improved from 0.12253 to 0.10381, saving model to best_CNN_model.h5
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0938 - accuracy: 0.9703 - val_loss: 0.1038 - val_accuracy: 0.9689
# Epoch 9/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0837 - accuracy: 0.9749
# Epoch 9: val_loss did not improve from 0.10381
# 70/70 [==============================] - 3s 37ms/step - loss: 0.0834 - accuracy: 0.9750 - val_loss: 0.1121 - val_accuracy: 0.9735
# Epoch 10/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0683 - accuracy: 0.9799
# Epoch 10: val_loss did not improve from 0.10381
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0684 - accuracy: 0.9798 - val_loss: 0.1063 - val_accuracy: 0.9732
# Epoch 11/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0658 - accuracy: 0.9791
# Epoch 11: val_loss improved from 0.10381 to 0.08478, saving model to best_CNN_model.h5
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0658 - accuracy: 0.9791 - val_loss: 0.0848 - val_accuracy: 0.9753
# Epoch 12/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0552 - accuracy: 0.9829
# Epoch 12: val_loss did not improve from 0.08478
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0552 - accuracy: 0.9829 - val_loss: 0.1282 - val_accuracy: 0.9669
# Epoch 13/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0482 - accuracy: 0.9845
# Epoch 13: val_loss improved from 0.08478 to 0.07820, saving model to best_CNN_model.h5
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0485 - accuracy: 0.9844 - val_loss: 0.0782 - val_accuracy: 0.9769
# Epoch 14/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0505 - accuracy: 0.9843
# Epoch 14: val_loss improved from 0.07820 to 0.07057, saving model to best_CNN_model.h5
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0509 - accuracy: 0.9843 - val_loss: 0.0706 - val_accuracy: 0.9798
# Epoch 15/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0433 - accuracy: 0.9867
# Epoch 15: val_loss did not improve from 0.07057
# 70/70 [==============================] - 3s 37ms/step - loss: 0.0437 - accuracy: 0.9866 - val_loss: 0.0798 - val_accuracy: 0.9760
# Epoch 16/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0378 - accuracy: 0.9883
# Epoch 16: val_loss did not improve from 0.07057
# 70/70 [==============================] - 3s 40ms/step - loss: 0.0376 - accuracy: 0.9883 - val_loss: 0.1259 - val_accuracy: 0.9721
# Epoch 17/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0379 - accuracy: 0.9883
# Epoch 17: val_loss did not improve from 0.07057
# 70/70 [==============================] - 3s 41ms/step - loss: 0.0379 - accuracy: 0.9884 - val_loss: 0.0832 - val_accuracy: 0.9746
# Epoch 18/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0338 - accuracy: 0.9897
# Epoch 18: val_loss did not improve from 0.07057
# 70/70 [==============================] - 3s 40ms/step - loss: 0.0340 - accuracy: 0.9897 - val_loss: 0.0877 - val_accuracy: 0.9791
# Epoch 19/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0321 - accuracy: 0.9905
# Epoch 19: val_loss did not improve from 0.07057
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0320 - accuracy: 0.9905 - val_loss: 0.1042 - val_accuracy: 0.9776
# Epoch 20/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0280 - accuracy: 0.9912
# Epoch 20: val_loss did not improve from 0.07057
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0279 - accuracy: 0.9913 - val_loss: 0.1144 - val_accuracy: 0.9785
# Epoch 21/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0286 - accuracy: 0.9909
# Epoch 21: val_loss did not improve from 0.07057
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0285 - accuracy: 0.9909 - val_loss: 0.1219 - val_accuracy: 0.9757
# Epoch 22/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0277 - accuracy: 0.9914
# Epoch 22: val_loss did not improve from 0.07057
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0276 - accuracy: 0.9915 - val_loss: 0.0944 - val_accuracy: 0.9812
# Epoch 23/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0258 - accuracy: 0.9917
# Epoch 23: val_loss did not improve from 0.07057
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0256 - accuracy: 0.9917 - val_loss: 0.0975 - val_accuracy: 0.9771
# Epoch 24/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0224 - accuracy: 0.9931
# Epoch 24: val_loss did not improve from 0.07057
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0224 - accuracy: 0.9931 - val_loss: 0.0879 - val_accuracy: 0.9794
# Epoch 25/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0233 - accuracy: 0.9920
# Epoch 25: val_loss did not improve from 0.07057
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0233 - accuracy: 0.9920 - val_loss: 0.0793 - val_accuracy: 0.9830
# Epoch 26/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0231 - accuracy: 0.9926
# Epoch 26: val_loss did not improve from 0.07057
# 70/70 [==============================] - 3s 40ms/step - loss: 0.0230 - accuracy: 0.9927 - val_loss: 0.0946 - val_accuracy: 0.9810
# Epoch 27/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0185 - accuracy: 0.9942
# Epoch 27: val_loss did not improve from 0.07057
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0184 - accuracy: 0.9943 - val_loss: 0.0851 - val_accuracy: 0.9812
# Epoch 28/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0208 - accuracy: 0.9938
# Epoch 28: val_loss did not improve from 0.07057
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0210 - accuracy: 0.9937 - val_loss: 0.1171 - val_accuracy: 0.9821
# Epoch 29/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0191 - accuracy: 0.9941
# Epoch 29: val_loss did not improve from 0.07057
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0191 - accuracy: 0.9941 - val_loss: 0.0966 - val_accuracy: 0.9805
# Epoch 30/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0188 - accuracy: 0.9941
# Epoch 30: val_loss did not improve from 0.07057
# 70/70 [==============================] - 3s 40ms/step - loss: 0.0188 - accuracy: 0.9941 - val_loss: 0.0940 - val_accuracy: 0.9800
# Epoch 31/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0208 - accuracy: 0.9938
# Epoch 31: val_loss did not improve from 0.07057
# 70/70 [==============================] - 3s 41ms/step - loss: 0.0209 - accuracy: 0.9938 - val_loss: 0.1023 - val_accuracy: 0.9812
# Epoch 32/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0191 - accuracy: 0.9940
# Epoch 32: val_loss did not improve from 0.07057
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0191 - accuracy: 0.9940 - val_loss: 0.1077 - val_accuracy: 0.9821
# Epoch 33/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0192 - accuracy: 0.9937
# Epoch 33: val_loss did not improve from 0.07057
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0191 - accuracy: 0.9938 - val_loss: 0.1267 - val_accuracy: 0.9798
# Epoch 34/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0149 - accuracy: 0.9952
# Epoch 34: val_loss did not improve from 0.07057
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0149 - accuracy: 0.9952 - val_loss: 0.0835 - val_accuracy: 0.9837
# Epoch 35/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0182 - accuracy: 0.9943
# Epoch 35: val_loss did not improve from 0.07057
# 70/70 [==============================] - 3s 40ms/step - loss: 0.0182 - accuracy: 0.9943 - val_loss: 0.0979 - val_accuracy: 0.9782
# Epoch 36/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0173 - accuracy: 0.9946
# Epoch 36: val_loss did not improve from 0.07057
# 70/70 [==============================] - 3s 40ms/step - loss: 0.0175 - accuracy: 0.9945 - val_loss: 0.0876 - val_accuracy: 0.9807
# Epoch 37/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0158 - accuracy: 0.9950
# Epoch 37: val_loss did not improve from 0.07057
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0157 - accuracy: 0.9950 - val_loss: 0.0946 - val_accuracy: 0.9794
# Epoch 38/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0149 - accuracy: 0.9949
# Epoch 38: val_loss improved from 0.07057 to 0.05893, saving model to best_CNN_model.h5
# 70/70 [==============================] - 3s 40ms/step - loss: 0.0148 - accuracy: 0.9950 - val_loss: 0.0589 - val_accuracy: 0.9848
# Epoch 39/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0178 - accuracy: 0.9946
# Epoch 39: val_loss did not improve from 0.05893
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0177 - accuracy: 0.9946 - val_loss: 0.0714 - val_accuracy: 0.9825
# Epoch 40/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0128 - accuracy: 0.9959
# Epoch 40: val_loss did not improve from 0.05893
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0127 - accuracy: 0.9959 - val_loss: 0.0866 - val_accuracy: 0.9821
# Epoch 41/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0158 - accuracy: 0.9948
# Epoch 41: val_loss did not improve from 0.05893
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0157 - accuracy: 0.9949 - val_loss: 0.0739 - val_accuracy: 0.9832
# Epoch 42/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0126 - accuracy: 0.9958
# Epoch 42: val_loss did not improve from 0.05893
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0125 - accuracy: 0.9959 - val_loss: 0.1201 - val_accuracy: 0.9800
# Epoch 43/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0122 - accuracy: 0.9959
# Epoch 43: val_loss did not improve from 0.05893
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0123 - accuracy: 0.9959 - val_loss: 0.1120 - val_accuracy: 0.9846
# Epoch 44/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0159 - accuracy: 0.9950
# Epoch 44: val_loss did not improve from 0.05893
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0158 - accuracy: 0.9950 - val_loss: 0.1126 - val_accuracy: 0.9839
# Epoch 45/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0150 - accuracy: 0.9960
# Epoch 45: val_loss did not improve from 0.05893
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0149 - accuracy: 0.9960 - val_loss: 0.0995 - val_accuracy: 0.9816
# Epoch 46/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0135 - accuracy: 0.9956
# Epoch 46: val_loss did not improve from 0.05893
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0134 - accuracy: 0.9956 - val_loss: 0.0794 - val_accuracy: 0.9837
# Epoch 47/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0121 - accuracy: 0.9963
# Epoch 47: val_loss did not improve from 0.05893
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0122 - accuracy: 0.9963 - val_loss: 0.0736 - val_accuracy: 0.9837
# Epoch 48/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0159 - accuracy: 0.9954
# Epoch 48: val_loss improved from 0.05893 to 0.04905, saving model to best_CNN_model.h5
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0158 - accuracy: 0.9954 - val_loss: 0.0490 - val_accuracy: 0.9868
# Epoch 49/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0107 - accuracy: 0.9965
# Epoch 49: val_loss did not improve from 0.04905
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0108 - accuracy: 0.9965 - val_loss: 0.0911 - val_accuracy: 0.9819
# Epoch 50/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0142 - accuracy: 0.9956
# Epoch 50: val_loss did not improve from 0.04905
# 70/70 [==============================] - 3s 40ms/step - loss: 0.0141 - accuracy: 0.9956 - val_loss: 0.0657 - val_accuracy: 0.9819
# Epoch 51/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0117 - accuracy: 0.9961
# Epoch 51: val_loss did not improve from 0.04905
# 70/70 [==============================] - 3s 37ms/step - loss: 0.0116 - accuracy: 0.9961 - val_loss: 0.0827 - val_accuracy: 0.9794
# Epoch 52/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0120 - accuracy: 0.9962
# Epoch 52: val_loss did not improve from 0.04905
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0121 - accuracy: 0.9962 - val_loss: 0.0824 - val_accuracy: 0.9850
# Epoch 53/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0130 - accuracy: 0.9961
# Epoch 53: val_loss improved from 0.04905 to 0.04233, saving model to best_CNN_model.h5
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0130 - accuracy: 0.9961 - val_loss: 0.0423 - val_accuracy: 0.9859
# Epoch 54/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0094 - accuracy: 0.9967
# Epoch 54: val_loss did not improve from 0.04233
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0094 - accuracy: 0.9967 - val_loss: 0.0766 - val_accuracy: 0.9846
# Epoch 55/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0127 - accuracy: 0.9961
# Epoch 55: val_loss did not improve from 0.04233
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0127 - accuracy: 0.9961 - val_loss: 0.0792 - val_accuracy: 0.9830
# Epoch 56/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0116 - accuracy: 0.9964
# Epoch 56: val_loss did not improve from 0.04233
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0115 - accuracy: 0.9964 - val_loss: 0.0857 - val_accuracy: 0.9855
# Epoch 57/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0127 - accuracy: 0.9958
# Epoch 57: val_loss did not improve from 0.04233
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0127 - accuracy: 0.9957 - val_loss: 0.0794 - val_accuracy: 0.9841
# Epoch 58/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0086 - accuracy: 0.9972
# Epoch 58: val_loss did not improve from 0.04233
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.1136 - val_accuracy: 0.9841
# Epoch 59/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0097 - accuracy: 0.9969
# Epoch 59: val_loss did not improve from 0.04233
# 70/70 [==============================] - 3s 40ms/step - loss: 0.0098 - accuracy: 0.9969 - val_loss: 0.1101 - val_accuracy: 0.9853
# Epoch 60/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0079 - accuracy: 0.9976
# Epoch 60: val_loss did not improve from 0.04233
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0079 - accuracy: 0.9976 - val_loss: 0.1551 - val_accuracy: 0.9832
# Epoch 61/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0080 - accuracy: 0.9976
# Epoch 61: val_loss did not improve from 0.04233
# 70/70 [==============================] - 3s 40ms/step - loss: 0.0082 - accuracy: 0.9976 - val_loss: 0.1203 - val_accuracy: 0.9839
# Epoch 62/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0136 - accuracy: 0.9961
# Epoch 62: val_loss did not improve from 0.04233
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0136 - accuracy: 0.9960 - val_loss: 0.1259 - val_accuracy: 0.9812
# Epoch 63/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0136 - accuracy: 0.9960
# Epoch 63: val_loss did not improve from 0.04233
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0135 - accuracy: 0.9961 - val_loss: 0.0791 - val_accuracy: 0.9821
# Epoch 64/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0107 - accuracy: 0.9964
# Epoch 64: val_loss did not improve from 0.04233
# 70/70 [==============================] - 3s 40ms/step - loss: 0.0107 - accuracy: 0.9964 - val_loss: 0.0614 - val_accuracy: 0.9853
# Epoch 65/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0126 - accuracy: 0.9963
# Epoch 65: val_loss did not improve from 0.04233
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0126 - accuracy: 0.9963 - val_loss: 0.0710 - val_accuracy: 0.9848
# Epoch 66/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0088 - accuracy: 0.9975
# Epoch 66: val_loss did not improve from 0.04233
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0087 - accuracy: 0.9976 - val_loss: 0.1200 - val_accuracy: 0.9814
# Epoch 67/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0101 - accuracy: 0.9972
# Epoch 67: val_loss did not improve from 0.04233
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0101 - accuracy: 0.9972 - val_loss: 0.0530 - val_accuracy: 0.9889
# Epoch 68/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0095 - accuracy: 0.9972
# Epoch 68: val_loss did not improve from 0.04233
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0095 - accuracy: 0.9972 - val_loss: 0.0591 - val_accuracy: 0.9853
# Epoch 69/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0097 - accuracy: 0.9972
# Epoch 69: val_loss improved from 0.04233 to 0.03298, saving model to best_CNN_model.h5
# 70/70 [==============================] - 3s 41ms/step - loss: 0.0097 - accuracy: 0.9972 - val_loss: 0.0330 - val_accuracy: 0.9934
# Epoch 70/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0107 - accuracy: 0.9967
# Epoch 70: val_loss did not improve from 0.03298
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0108 - accuracy: 0.9967 - val_loss: 0.0768 - val_accuracy: 0.9819
# Epoch 71/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0099 - accuracy: 0.9971
# Epoch 71: val_loss did not improve from 0.03298
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0098 - accuracy: 0.9971 - val_loss: 0.0428 - val_accuracy: 0.9873
# Epoch 72/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0071 - accuracy: 0.9979
# Epoch 72: val_loss did not improve from 0.03298
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0070 - accuracy: 0.9979 - val_loss: 0.1021 - val_accuracy: 0.9834
# Epoch 73/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0066 - accuracy: 0.9977
# Epoch 73: val_loss did not improve from 0.03298
# 70/70 [==============================] - 3s 40ms/step - loss: 0.0066 - accuracy: 0.9977 - val_loss: 0.0961 - val_accuracy: 0.9832
# Epoch 74/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0095 - accuracy: 0.9970
# Epoch 74: val_loss did not improve from 0.03298
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0095 - accuracy: 0.9970 - val_loss: 0.0858 - val_accuracy: 0.9821
# Epoch 75/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0075 - accuracy: 0.9974
# Epoch 75: val_loss did not improve from 0.03298
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0074 - accuracy: 0.9974 - val_loss: 0.1292 - val_accuracy: 0.9846
# Epoch 76/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0091 - accuracy: 0.9972
# Epoch 76: val_loss did not improve from 0.03298
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0091 - accuracy: 0.9972 - val_loss: 0.1289 - val_accuracy: 0.9791
# Epoch 77/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0135 - accuracy: 0.9961
# Epoch 77: val_loss did not improve from 0.03298
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0134 - accuracy: 0.9961 - val_loss: 0.0732 - val_accuracy: 0.9844
# Epoch 78/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0060 - accuracy: 0.9980
# Epoch 78: val_loss did not improve from 0.03298
# 70/70 [==============================] - 3s 40ms/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.0823 - val_accuracy: 0.9866
# Epoch 79/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0069 - accuracy: 0.9980
# Epoch 79: val_loss did not improve from 0.03298
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0069 - accuracy: 0.9980 - val_loss: 0.1268 - val_accuracy: 0.9823
# Epoch 80/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0136 - accuracy: 0.9962
# Epoch 80: val_loss did not improve from 0.03298
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0134 - accuracy: 0.9962 - val_loss: 0.0519 - val_accuracy: 0.9882
# Epoch 81/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0088 - accuracy: 0.9974
# Epoch 81: val_loss did not improve from 0.03298
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0088 - accuracy: 0.9974 - val_loss: 0.0566 - val_accuracy: 0.9902
# Epoch 82/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0108 - accuracy: 0.9970
# Epoch 82: val_loss did not improve from 0.03298
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0108 - accuracy: 0.9970 - val_loss: 0.0836 - val_accuracy: 0.9830
# Epoch 83/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0080 - accuracy: 0.9978
# Epoch 83: val_loss did not improve from 0.03298
# 70/70 [==============================] - 3s 41ms/step - loss: 0.0081 - accuracy: 0.9978 - val_loss: 0.0774 - val_accuracy: 0.9844
# Epoch 84/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0107 - accuracy: 0.9968
# Epoch 84: val_loss did not improve from 0.03298
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0108 - accuracy: 0.9968 - val_loss: 0.1077 - val_accuracy: 0.9862
# Epoch 85/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0112 - accuracy: 0.9971
# Epoch 85: val_loss did not improve from 0.03298
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0112 - accuracy: 0.9971 - val_loss: 0.0436 - val_accuracy: 0.9916
# Epoch 86/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0110 - accuracy: 0.9970
# Epoch 86: val_loss improved from 0.03298 to 0.03074, saving model to best_CNN_model.h5
# 70/70 [==============================] - 3s 40ms/step - loss: 0.0112 - accuracy: 0.9970 - val_loss: 0.0307 - val_accuracy: 0.9925
# Epoch 87/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0063 - accuracy: 0.9983
# Epoch 87: val_loss did not improve from 0.03074
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0063 - accuracy: 0.9983 - val_loss: 0.0518 - val_accuracy: 0.9900
# Epoch 88/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0083 - accuracy: 0.9972
# Epoch 88: val_loss did not improve from 0.03074
# 70/70 [==============================] - 3s 40ms/step - loss: 0.0082 - accuracy: 0.9972 - val_loss: 0.0503 - val_accuracy: 0.9880
# Epoch 89/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0093 - accuracy: 0.9976
# Epoch 89: val_loss did not improve from 0.03074
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0093 - accuracy: 0.9976 - val_loss: 0.0578 - val_accuracy: 0.9866
# Epoch 90/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0113 - accuracy: 0.9967
# Epoch 90: val_loss did not improve from 0.03074
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0113 - accuracy: 0.9967 - val_loss: 0.0434 - val_accuracy: 0.9909
# Epoch 91/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0062 - accuracy: 0.9981
# Epoch 91: val_loss did not improve from 0.03074
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0063 - accuracy: 0.9981 - val_loss: 0.0402 - val_accuracy: 0.9925
# Epoch 92/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0104 - accuracy: 0.9969
# Epoch 92: val_loss did not improve from 0.03074
# 70/70 [==============================] - 3s 41ms/step - loss: 0.0103 - accuracy: 0.9969 - val_loss: 0.0410 - val_accuracy: 0.9882
# Epoch 93/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0065 - accuracy: 0.9981
# Epoch 93: val_loss did not improve from 0.03074
# 70/70 [==============================] - 3s 41ms/step - loss: 0.0065 - accuracy: 0.9982 - val_loss: 0.0481 - val_accuracy: 0.9907
# Epoch 94/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0081 - accuracy: 0.9976
# Epoch 94: val_loss did not improve from 0.03074
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0080 - accuracy: 0.9976 - val_loss: 0.0350 - val_accuracy: 0.9907
# Epoch 95/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0044 - accuracy: 0.9988
# Epoch 95: val_loss did not improve from 0.03074
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.0395 - val_accuracy: 0.9923
# Epoch 96/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0087 - accuracy: 0.9976
# Epoch 96: val_loss did not improve from 0.03074
# 70/70 [==============================] - 3s 37ms/step - loss: 0.0086 - accuracy: 0.9976 - val_loss: 0.0325 - val_accuracy: 0.9918
# Epoch 97/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0066 - accuracy: 0.9978
# Epoch 97: val_loss improved from 0.03074 to 0.02896, saving model to best_CNN_model.h5
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0066 - accuracy: 0.9978 - val_loss: 0.0290 - val_accuracy: 0.9907
# Epoch 98/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0061 - accuracy: 0.9981
# Epoch 98: val_loss did not improve from 0.02896
# 70/70 [==============================] - 3s 39ms/step - loss: 0.0061 - accuracy: 0.9982 - val_loss: 0.0419 - val_accuracy: 0.9907
# Epoch 99/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0068 - accuracy: 0.9981
# Epoch 99: val_loss did not improve from 0.02896
# 70/70 [==============================] - 3s 38ms/step - loss: 0.0067 - accuracy: 0.9981 - val_loss: 0.0652 - val_accuracy: 0.9868
# Epoch 100/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0090 - accuracy: 0.9976
# Epoch 100: val_loss did not improve from 0.02896
# 70/70 [==============================] - 3s 37ms/step - loss: 0.0090 - accuracy: 0.9976 - val_loss: 0.0620 - val_accuracy: 0.9875

# %%
from keras.models import Sequential, load_model

# Load the best trained model from the saved file
best_CNN_model = load_model('best_CNN_model.h5')

# Evaluate the model performance on the test data
evaluation_results = best_CNN_model.evaluate(X_test_gray_norm, y_test)
# Out:
# 395/395 [==============================] - 2s 3ms/step - loss: 0.1171 - accuracy: 0.9762

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming best_CNN_model and sign_names are already defined

# Predict on the test dataset
predictions = best_CNN_model.predict(X_test_gray_norm)
predicted_labels = np.argmax(predictions, axis=1)

# Map predicted labels to class names
predicted_classes = [sign_names[label] for label in predicted_labels]

# Calculate accuracy
accuracy = np.sum(predicted_labels == np.argmax(y_test, axis=1)) / len(y_test)
print("Accuracy on test dataset: {:.2%}".format(accuracy))

# Visualize the test dataset with real and predicted labels
num_rows = 4
num_cols = 5
plt.figure(figsize=(15, 12))

for i in range(num_rows * num_cols):
    plt.subplot(num_rows, num_cols, i + 1)
    plt.imshow(X_test[i], cmap='gray')
    plt.title("Real: {}\nPredicted: {}".format(sign_names[np.argmax(y_test[i])], predicted_classes[i]))
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 395/395 [==============================] - 1s 2ms/step
# Accuracy on test dataset: 97.62%

# %%
# !pip install gtts
# Out:
# Collecting gtts
#   Downloading gTTS-2.5.1-py3-none-any.whl (29 kB)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from gtts) (2.31.0)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.10/dist-packages (from gtts) (8.1.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (2024.2.2)
# Installing collected packages: gtts
# Successfully installed gtts-2.5.1

# %%
import numpy as np
from gtts import gTTS  # Google Text-to-Speech library
from IPython.display import Audio, display, HTML

# Assuming best_CNN_model and sign_names are already defined

# Predict on the test dataset
predictions = best_CNN_model.predict(X_test_gray_norm)
predicted_labels = np.argmax(predictions, axis=1)

# Map predicted labels to class names
predicted_classes = [sign_names[label] for label in predicted_labels]

# Calculate accuracy
accuracy = np.sum(predicted_labels == np.argmax(y_test, axis=1)) / len(y_test)
accuracy_percentage = "{:.2%}".format(accuracy)
accuracy_message = f"Accuracy on test dataset: {accuracy_percentage}"
print(accuracy_message)

# Provide real-time information through auditory feedback for the first 10 images
for i in range(1):
    real_label = sign_names[np.argmax(y_test[i])]
    predicted_label = predicted_classes[i]

    # Generate an auditory message
    print(f"Real sign: {real_label}")
    message = f"Predicted sign: {predicted_label}."
    print(message)

    # Convert text to speech and display as an audio widget in Colab
    tts = gTTS(message)
    tts.save("output.mp3")
    display(Audio("output.mp3", autoplay=True))

# Optionally, you can include tactile feedback using haptic devices if available.
# Out:
# 395/395 [==============================] - 1s 2ms/step
# Accuracy on test dataset: 97.62%
# Real sign: Vehicles over 3.5 metric tons prohibited
# Predicted sign: Vehicles over 3.5 metric tons prohibited.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Create subplots with two columns
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

# Plotting accuracy for model  on the left subplot
axes[0].plot(history.history['accuracy'], label='Training Accuracy')
axes[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
axes[0].set_title('Accuracy Plot for Model  (Convolutional Neural Network)')
axes[0].set_xlabel('Number of Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Plotting loss for model  on the right subplot
axes[1].plot(history.history['loss'], label='Training Loss')
axes[1].plot(history.history['val_loss'], label='Validation Loss')
axes[1].set_title('Loss Plot for Model  (Convolutional Neural Network)')
axes[1].set_xlabel('Number of Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

# Display the plots
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report

# Assuming you have predictions for X_test_gray_norm
y_pred = best_CNN_model.predict(X_test_gray_norm)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Compute confusion matrix
confusion_mtx = confusion_matrix(y_true_classes, y_pred_classes)

# Compute classification report
classification_rep = classification_report(y_true_classes, y_pred_classes)
print("\nClassification Report for Model 6 (CNN):")
print(classification_rep)
# Out:
# 395/395 [==============================] - 2s 4ms/step
#
# Classification Report for Model 6 (CNN):
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98        60
#            1       0.98      1.00      0.99       720
#            2       0.99      1.00      0.99       750
#            3       0.99      0.96      0.98       450
#            4       1.00      0.99      0.99       660
#            5       0.97      0.98      0.98       630
#            6       1.00      0.87      0.93       150
#            7       1.00      0.99      0.99       450
#            8       0.99      0.98      0.99       450
#            9       0.98      1.00      0.99       480
#           10       1.00      1.00      1.00       660
#           11       0.92      0.96      0.94       420
#           12       0.99      0.99      0.99       690
#           13       0.99      1.00      0.99       720
#           14       0.99      1.00      0.99       270
#           15       0.99      1.00      0.99       210
#           16       0.98      1.00      0.99       150
#           17       1.00      0.99      0.99       360
#           18       0.99      0.89      0.94       390
#           19       0.91      1.00      0.95        60
#           20       0.98      1.00      0.99        90
#           21       0.98      0.68      0.80        90
#           22       0.99      0.97      0.98       120
#           23       0.88      1.00      0.94       150
#           24       0.96      0.98      0.97        90
#           25       0.97      0.99      0.98       480
#           26       0.96      0.96      0.96       180
#           27       0.54      0.52      0.53        60
#           28       0.95      1.00      0.97       150
#           29       0.88      1.00      0.94        90
#           30       0.88      0.89      0.88       150
#           31       0.99      1.00      1.00       270
#           32       0.92      1.00      0.96        60
#           33       1.00      0.98      0.99       210
#           34       0.98      1.00      0.99       120
#           35       0.99      0.98      0.98       390
#           36       0.98      1.00      0.99       120
#           37       0.81      1.00      0.90        60
#           38       0.99      0.95      0.97       690
#           39       0.90      0.99      0.94        90
#           40       0.89      0.94      0.92        90
#           41       0.98      0.90      0.94        60
#           42       0.94      1.00      0.97        90
#
#     accuracy                           0.98     12630
#    macro avg       0.95      0.96      0.96     12630
# weighted avg       0.98      0.98      0.98     12630

# %%
import seaborn as sns
# Plot the confusion matrix
plt.figure(figsize=(17, 17))
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix for Model 6 (CNN)')
plt.show()
